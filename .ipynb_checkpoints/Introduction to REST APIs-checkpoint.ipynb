# %%
import requests

# %%
resp = requests.get("https://docs.python.org/3/")

# %%
resp
# Out:
# <Response [200]>

# %%
resp.status_code
# Out:
# 200

# %%
resp.reason
# Out:
# 'OK'

# %%
resp.headers
# Out:
# {'Connection': 'keep-alive', 'Content-Length': '3426', 'server': 'nginx', 'content-type': 'text/html', 'last-modified': 'Tue, 26 Mar 2024 21:52:45 GMT', 'etag': '"660343ad-4097"', 'x-clacks-overhead': 'GNU Terry Pratchett', 'strict-transport-security': 'max-age=315360000; includeSubDomains; preload', 'Content-Encoding': 'gzip', 'Via': '1.1 varnish, 1.1 varnish', 'Accept-Ranges': 'bytes', 'Date': 'Wed, 27 Mar 2024 11:31:12 GMT', 'Age': '49079', 'X-Served-By': 'cache-lga21956-LGA, cache-del21734-DEL', 'X-Cache': 'HIT, HIT', 'X-Cache-Hits': '50, 1', 'X-Timer': 'S1711539073.752591,VS0,VE1', 'Vary': 'Accept-Encoding'}

# %%
resp.reason
# Out:
# 'OK'

# %%
resp.content
# Out:
# b'<!DOCTYPE html>\n\n<html lang="en" data-content_root="./">\n  <head>\n    <meta charset="utf-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1.0" /><title>3.12.2 Documentation</title><meta name="viewport" content="width=device-width, initial-scale=1.0">\n    \n    <link rel="stylesheet" type="text/css" href="_static/pygments.css?v=80d5e7a1" />\n    <link rel="stylesheet" type="text/css" href="_static/pydoctheme.css?v=a35cb577" />\n    <link id="pygments_dark_css" media="(prefers-color-scheme: dark)" rel="stylesheet" type="text/css" href="_static/pygments_dark.css?v=b20cc3f5" />\n    \n    <script src="_static/documentation_options.js?v=88fa046d"></script>\n    <script src="_static/doctools.js?v=888ff710"></script>\n    <script src="_static/sphinx_highlight.js?v=dc90522c"></script>\n    \n    <script src="_static/sidebar.js"></script>\n    \n    <link rel="search" type="application/opensearchdescription+xml"\n          title="Search within Python 3.12.2 d
# ...

# %%
url = "https://img.freepik.com/free-photo/painting-mountain-lake-with-mountain-background_188544-9126.jpg?w=1060&t=st=1711022681~exp=1711023281~hmac=ec54e012c153e894913b508f3e52c409e1f47ddb532e1d8ea9029d3cc77b25ad"

# %%
resp = requests.get(url)

# %%
resp
# Out:
# <Response [200]>

# %%
data = resp.content
data
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xe2\x02\x1cICC_PROFILE\x00\x01\x01\x00\x00\x02\x0clcms\x02\x10\x00\x00mntrRGB XYZ \x07\xdc\x00\x01\x00\x19\x00\x03\x00)\x009acspAPPL\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf6\xd6\x00\x01\x00\x00\x00\x00\xd3-lcms\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\ndesc\x00\x00\x00\xfc\x00\x00\x00^cprt\x00\x00\x01\\\x00\x00\x00\x0bwtpt\x00\x00\x01h\x00\x00\x00\x14bkpt\x00\x00\x01|\x00\x00\x00\x14rXYZ\x00\x00\x01\x90\x00\x00\x00\x14gXYZ\x00\x00\x01\xa4\x00\x00\x00\x14bXYZ\x00\x00\x01\xb8\x00\x00\x00\x14rTRC\x00\x00\x01\xcc\x00\x00\x00@gTRC\x00\x00\x01\xcc\x00\x00\x00@bTRC\x00\x00\x01\xcc\x00\x00\x00@desc\x00\x00\x00\x00\x00\x00\x00\x03c2\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x
# ...

# %%
with open('img.jpeg', 'wb') as f:
    f.write(data)

# %%
url = "https://webhook.site/2cd95930-b85c-41b5-8ef4-22446fd4e4d8"

# %%
dict1 = {'name':'harsh', 'age':25, 'address':'jaipur'}

# %%
requests.post(url, data=dict1)
# Out:
# <Response [200]>

# %%
requests.post(url, json=dict1)
# Out:
# <Response [200]>

# %%
26°54′N 75°48′E

# %%
lat = 25.54
lon = 75.48
api_key = 'fd4990f3b8581815656c8049597e35e1'

url = f"https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={api_key}"

# %%
print(url)
# Out:
# https://api.openweathermap.org/data/2.5/weather?lat=25.54&lon=75.48&appid=fd4990f3b8581815656c8049597e35e1

# %%
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
resp.headers
# Out:
# {'Server': 'openresty', 'Date': 'Wed, 27 Mar 2024 11:58:00 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '501', 'Connection': 'keep-alive', 'X-Cache-Key': '/data/2.5/weather?lat=25.54&lon=75.48', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true', 'Access-Control-Allow-Methods': 'GET, POST'}

# %%
resp.content
# Out:
# b'{"coord":{"lon":75.48,"lat":25.54},"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04d"}],"base":"stations","main":{"temp":311.49,"feels_like":309.08,"temp_min":311.49,"temp_max":311.49,"pressure":1008,"humidity":14,"sea_level":1008,"grnd_level":972},"visibility":10000,"wind":{"speed":3.66,"deg":345,"gust":3.79},"clouds":{"all":86},"dt":1711540680,"sys":{"country":"IN","sunrise":1711500869,"sunset":1711545128},"timezone":19800,"id":1442037,"name":"Borkhera","cod":200}'

# %%
data = resp.json()
data
# Out:
# {'coord': {'lon': 75.48, 'lat': 25.54},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 311.49,
#   'feels_like': 309.08,
#   'temp_min': 311.49,
#   'temp_max': 311.49,
#   'pressure': 1008,
#   'humidity': 14,
#   'sea_level': 1008,
#   'grnd_level': 972},
#  'visibility': 10000,
#  'wind': {'speed': 3.66, 'deg': 345, 'gust': 3.79},
#  'clouds': {'all': 86},
#  'dt': 1711540680,
#  'sys': {'country': 'IN', 'sunrise': 1711500869, 'sunset': 1711545128},
#  'timezone': 19800,
#  'id': 1442037,
#  'name': 'Borkhera',
#  'cod': 200}

# %%
data.keys()
# Out:
# dict_keys(['coord', 'weather', 'base', 'main', 'visibility', 'wind', 'clouds', 'dt', 'sys', 'timezone', 'id', 'name', 'cod'])

# %%
data['main']['temp']
# Out:
# 311.49

# %%
data['main']['temp_min']
# Out:
# 311.49

# %%
data['main']['temp_max']
# Out:
# 311.49
