# %%
api_key = "fsq3/qWKdb9qPqlEThP0P7+f2kX52mr7qCPxMoBZAg3Ba/U="

# %%
import requests

url = "https://api.foursquare.com/v3/places/search"

params = {
    "query": "coffee",
    "ll": "26.9124,75.7873",
    "open_now": "true",
    "sort":"DISTANCE"
}

headers = {
    "Accept": "application/json",
    "Authorization": api_key
}

resp = requests.get(url, params=params, headers=headers)
resp
# Out:
# <Response [200]>

# %%
resp.content
# Out:
# b'{"results":[{"fsq_id":"5c8f5d8cdeb49500259aa796","categories":[{"id":13034,"name":"Caf\xc3\xa9","short_name":"Caf\xc3\xa9","plural_name":"Caf\xc3\xa9s","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/cafe_","suffix":".png"}}],"chains":[],"closed_bucket":"Unsure","distance":805,"geocodes":{"main":{"latitude":26.905228,"longitude":75.786299}},"link":"/v3/places/5c8f5d8cdeb49500259aa796","location":{"address":"28 Civil Lines Road, Shivaji Nagar, Suraj","country":"IN","cross_street":"","formatted_address":"28 Civil Lines Road, Shivaji Nagar, Suraj, Jaipur 302006, R\xc4\x81jasth\xc4\x81n","locality":"Jaipur","postcode":"302006","region":"R\xc4\x81jasth\xc4\x81n"},"name":"Cafe Kothi","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"50081e28e4b05eac5b27a1e9","categories":[{"id":13002,"name":"Bakery","short_name":"Bakery","plural_name":"Bakeries","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/bakery_","suffix":".png"}},{"id":13034,"name":"Caf\xc3\xa9","short_name":"Caf\xc3\xa9","plural_name":"Caf\xc3\xa9s","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/cafe_","suffix":".png"}},{"id":13065,"name":"Restaurant","short_name":"Restaurant","plural_name":"Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"chains":[],"closed_bucket":"Unsure","distance":849,"geocodes":{"main":{"latitude":26.915614,"longitude":75.794941}},"link":"/v3/places/50081e28e4b05eac5b27a1e9","location":{"country":"IN","cross_street":"","formatted_address":"941735, R\xc4\x81jasth\xc4\x81n","postcode":"941735","region":"R\xc4\x81jasth\xc4\x81n"},"name":"NIBS- The Chocolate Workshop","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"5bb75785bf7dde002cee3d87","categories":[{"id":13034,"name":"Caf\xc3\xa9","short_name":"Caf\xc3\xa9","plural_name":"Caf\xc3\xa9s","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/cafe_","suffix":".png"}},{"id":13065,"name":"Restaurant","short_name":"Restaurant","plural_name":"Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"chains":[],"closed_bucket":"LikelyOpen","distance":1065,"geocodes":{"main":{"latitude":26.905237,"longitude":75.794367}},"link":"/v3/places/5bb75785bf7dde002cee3d87","location":{"country":"IN","cross_street":"","formatted_address":"Jaipur 302001, R\xc4\x81jasth\xc4\x81n","locality":"Jaipur","postcode":"302001","region":"R\xc4\x81jasth\xc4\x81n"},"name":"Poppin Cafe","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"5aa968f9dd84424438483cef","categories":[{"id":13199,"name":"Indian Restaurant","short_name":"Indian","plural_name":"Indian Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/indian_","suffix":".png"}}],"chains":[],"closed_bucket":"LikelyOpen","distance":1113,"geocodes":{"main":{"latitude":26.919592,"longitude":75.794788},"roof":{"latitude":26.919592,"longitude":75.794788}},"link":"/v3/places/5aa968f9dd84424438483cef","location":{"address":"Radisson Jaipur City Center, Khasa Kothi Circle, Mi Road","country":"IN","cross_street":"","formatted_address":"Radisson Jaipur City Center, Khasa Kothi Circle, Mi Road, Jaipur 302001, R\xc4\x81jasth\xc4\x81n","locality":"Jaipur","postcode":"302001","region":"R\xc4\x81jasth\xc4\x81n"},"name":"Farzi Cafe","related_places":{},"timezone":"Asia/Kolkata"},{"fsq_id":"f07534203aea47efab86e586","categories":[{"id":13034,"name":"Caf\xc3\xa9","short_name":"Caf\xc3\xa9","plural_name":"Caf\xc3\xa9s","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/cafe_","suffix":".png"}},{"id":13145,"name":"Fast Food Restaurant","short_name":"Fast Food","plural_name":"Fast Food Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/fastfood_","suffix":".png"}}],"chains":[],"closed_bucket":"LikelyOpen","distance":1135,"geocodes":{"main":{"latitude":26.90622,"longitude":75.796424}},"link":"/v3/places/f07534203aea47efab86e586","location":{"address":"J-1, Jamna Lal ...

# %%
data = resp.json()
print(data)
# Out:
# {'results': [{'fsq_id': '5c8f5d8cdeb49500259aa796', 'categories': [{'id': 13034, 'name': 'Café', 'short_name': 'Café', 'plural_name': 'Cafés', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_', 'suffix': '.png'}}], 'chains': [], 'closed_bucket': 'Unsure', 'distance': 805, 'geocodes': {'main': {'latitude': 26.905228, 'longitude': 75.786299}}, 'link': '/v3/places/5c8f5d8cdeb49500259aa796', 'location': {'address': '28 Civil Lines Road, Shivaji Nagar, Suraj', 'country': 'IN', 'cross_street': '', 'formatted_address': '28 Civil Lines Road, Shivaji Nagar, Suraj, Jaipur 302006, Rājasthān', 'locality': 'Jaipur', 'postcode': '302006', 'region': 'Rājasthān'}, 'name': 'Cafe Kothi', 'related_places': {}, 'timezone': 'Asia/Kolkata'}, {'fsq_id': '50081e28e4b05eac5b27a1e9', 'categories': [{'id': 13002, 'name': 'Bakery', 'short_name': 'Bakery', 'plural_name': 'Bakeries', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_', 'suffix': '.png'}}, {'id': 13034, 'name': 'Café', 'short_name': 'Café', 'plural_name': 'Cafés', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_', 'suffix': '.png'}}, {'id': 13065, 'name': 'Restaurant', 'short_name': 'Restaurant', 'plural_name': 'Restaurants', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_', 'suffix': '.png'}}], 'chains': [], 'closed_bucket': 'Unsure', 'distance': 849, 'geocodes': {'main': {'latitude': 26.915614, 'longitude': 75.794941}}, 'link': '/v3/places/50081e28e4b05eac5b27a1e9', 'location': {'country': 'IN', 'cross_street': '', 'formatted_address': '941735, Rājasthān', 'postcode': '941735', 'region': 'Rājasthān'}, 'name': 'NIBS- The Chocolate Workshop', 'related_places': {}, 'timezone': 'Asia/Kolkata'}, {'fsq_id': '5bb75785bf7dde002cee3d87', 'categories': [{'id': 13034, 'name': 'Café', 'short_name': 'Café', 'plural_name': 'Cafés', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_', 'suffix': '.png'}}, {'id': 13065, 'name': 'Restaurant', 'short_name': 'Restaurant', 'plural_name': 'Restaurants', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_', 'suffix': '.png'}}], 'chains': [], 'closed_bucket': 'LikelyOpen', 'distance': 1065, 'geocodes': {'main': {'latitude': 26.905237, 'longitude': 75.794367}}, 'link': '/v3/places/5bb75785bf7dde002cee3d87', 'location': {'country': 'IN', 'cross_street': '', 'formatted_address': 'Jaipur 302001, Rājasthān', 'locality': 'Jaipur', 'postcode': '302001', 'region': 'Rājasthān'}, 'name': 'Poppin Cafe', 'related_places': {}, 'timezone': 'Asia/Kolkata'}, {'fsq_id': '5aa968f9dd84424438483cef', 'categories': [{'id': 13199, 'name': 'Indian Restaurant', 'short_name': 'Indian', 'plural_name': 'Indian Restaurants', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}}], 'chains': [], 'closed_bucket': 'LikelyOpen', 'distance': 1113, 'geocodes': {'main': {'latitude': 26.919592, 'longitude': 75.794788}, 'roof': {'latitude': 26.919592, 'longitude': 75.794788}}, 'link': '/v3/places/5aa968f9dd84424438483cef', 'location': {'address': 'Radisson Jaipur City Center, Khasa Kothi Circle, Mi Road', 'country': 'IN', 'cross_street': '', 'formatted_address': 'Radisson Jaipur City Center, Khasa Kothi Circle, Mi Road, Jaipur 302001, Rājasthān', 'locality': 'Jaipur', 'postcode': '302001', 'region': 'Rājasthān'}, 'name': 'Farzi Cafe', 'related_places': {}, 'timezone': 'Asia/Kolkata'}, {'fsq_id': 'f07534203aea47efab86e586', 'categories': [{'id': 13034, 'name': 'Café', 'short_name': 'Café', 'plural_name': 'Cafés', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_', 'suffix': '.png'}}, {'id': 13145, 'name': 'Fast Food Restaurant', 'short_name': 'Fast Food', 'plural_name': 'Fast Food Restaurants', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_', 'suffix': '.png'}}], 'chains': [], 'closed_bucket': 'LikelyOpen', 'distance': 1135, 'geocodes': {'main': {'latitude': 26.90622, 'longitude': 75.796424 ...

# %%
data.keys()
# Out:
# dict_keys(['results', 'context'])

# %%
data = data['results']
print(data)
# Out:
# [{'fsq_id': '5c8f5d8cdeb49500259aa796', 'categories': [{'id': 13034, 'name': 'Café', 'short_name': 'Café', 'plural_name': 'Cafés', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_', 'suffix': '.png'}}], 'chains': [], 'closed_bucket': 'Unsure', 'distance': 805, 'geocodes': {'main': {'latitude': 26.905228, 'longitude': 75.786299}}, 'link': '/v3/places/5c8f5d8cdeb49500259aa796', 'location': {'address': '28 Civil Lines Road, Shivaji Nagar, Suraj', 'country': 'IN', 'cross_street': '', 'formatted_address': '28 Civil Lines Road, Shivaji Nagar, Suraj, Jaipur 302006, Rājasthān', 'locality': 'Jaipur', 'postcode': '302006', 'region': 'Rājasthān'}, 'name': 'Cafe Kothi', 'related_places': {}, 'timezone': 'Asia/Kolkata'}, {'fsq_id': '50081e28e4b05eac5b27a1e9', 'categories': [{'id': 13002, 'name': 'Bakery', 'short_name': 'Bakery', 'plural_name': 'Bakeries', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_', 'suffix': '.png'}}, {'id': 13034, 'name': 'Café', 'short_name': 'Café', 'plural_name': 'Cafés', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_', 'suffix': '.png'}}, {'id': 13065, 'name': 'Restaurant', 'short_name': 'Restaurant', 'plural_name': 'Restaurants', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_', 'suffix': '.png'}}], 'chains': [], 'closed_bucket': 'Unsure', 'distance': 849, 'geocodes': {'main': {'latitude': 26.915614, 'longitude': 75.794941}}, 'link': '/v3/places/50081e28e4b05eac5b27a1e9', 'location': {'country': 'IN', 'cross_street': '', 'formatted_address': '941735, Rājasthān', 'postcode': '941735', 'region': 'Rājasthān'}, 'name': 'NIBS- The Chocolate Workshop', 'related_places': {}, 'timezone': 'Asia/Kolkata'}, {'fsq_id': '5bb75785bf7dde002cee3d87', 'categories': [{'id': 13034, 'name': 'Café', 'short_name': 'Café', 'plural_name': 'Cafés', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_', 'suffix': '.png'}}, {'id': 13065, 'name': 'Restaurant', 'short_name': 'Restaurant', 'plural_name': 'Restaurants', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_', 'suffix': '.png'}}], 'chains': [], 'closed_bucket': 'LikelyOpen', 'distance': 1065, 'geocodes': {'main': {'latitude': 26.905237, 'longitude': 75.794367}}, 'link': '/v3/places/5bb75785bf7dde002cee3d87', 'location': {'country': 'IN', 'cross_street': '', 'formatted_address': 'Jaipur 302001, Rājasthān', 'locality': 'Jaipur', 'postcode': '302001', 'region': 'Rājasthān'}, 'name': 'Poppin Cafe', 'related_places': {}, 'timezone': 'Asia/Kolkata'}, {'fsq_id': '5aa968f9dd84424438483cef', 'categories': [{'id': 13199, 'name': 'Indian Restaurant', 'short_name': 'Indian', 'plural_name': 'Indian Restaurants', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_', 'suffix': '.png'}}], 'chains': [], 'closed_bucket': 'LikelyOpen', 'distance': 1113, 'geocodes': {'main': {'latitude': 26.919592, 'longitude': 75.794788}, 'roof': {'latitude': 26.919592, 'longitude': 75.794788}}, 'link': '/v3/places/5aa968f9dd84424438483cef', 'location': {'address': 'Radisson Jaipur City Center, Khasa Kothi Circle, Mi Road', 'country': 'IN', 'cross_street': '', 'formatted_address': 'Radisson Jaipur City Center, Khasa Kothi Circle, Mi Road, Jaipur 302001, Rājasthān', 'locality': 'Jaipur', 'postcode': '302001', 'region': 'Rājasthān'}, 'name': 'Farzi Cafe', 'related_places': {}, 'timezone': 'Asia/Kolkata'}, {'fsq_id': 'f07534203aea47efab86e586', 'categories': [{'id': 13034, 'name': 'Café', 'short_name': 'Café', 'plural_name': 'Cafés', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_', 'suffix': '.png'}}, {'id': 13145, 'name': 'Fast Food Restaurant', 'short_name': 'Fast Food', 'plural_name': 'Fast Food Restaurants', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_', 'suffix': '.png'}}], 'chains': [], 'closed_bucket': 'LikelyOpen', 'distance': 1135, 'geocodes': {'main': {'latitude': 26.90622, 'longitude': 75.796424}}, 'link':  ...

# %%
len(data)
# Out:
# 10

# %%
data[0]
# Out:
# {'fsq_id': '5c8f5d8cdeb49500259aa796',
#  'categories': [{'id': 13034,
#    'name': 'Café',
#    'short_name': 'Café',
#    'plural_name': 'Cafés',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#     'suffix': '.png'}}],
#  'chains': [],
#  'closed_bucket': 'Unsure',
#  'distance': 805,
#  'geocodes': {'main': {'latitude': 26.905228, 'longitude': 75.786299}},
#  'link': '/v3/places/5c8f5d8cdeb49500259aa796',
#  'location': {'address': '28 Civil Lines Road, Shivaji Nagar, Suraj',
#   'country': 'IN',
#   'cross_street': '',
#   'formatted_address': '28 Civil Lines Road, Shivaji Nagar, Suraj, Jaipur 302006, Rājasthān',
#   'locality': 'Jaipur',
#   'postcode': '302006',
#   'region': 'Rājasthān'},
#  'name': 'Cafe Kothi',
#  'related_places': {},
#  'timezone': 'Asia/Kolkata'}

# %%
data[0]['name']
# Out:
# 'Cafe Kothi'

# %%
data[0]['location']['formatted_address']
# Out:
# '28 Civil Lines Road, Shivaji Nagar, Suraj, Jaipur 302006, Rājasthān'

# %%
for i in data:
    name = i['name']
    address = i['location']['formatted_address']
    print(f"Place Name: {name}")
    print(f"Place Address {address}")
    print('-'*100)
    print('-'*100)    
    print()
# Out:
# Place Name: Cafe Kothi
# Place Address 28 Civil Lines Road, Shivaji Nagar, Suraj, Jaipur 302006, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Place Name: NIBS- The Chocolate Workshop
# Place Address 941735, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Place Name: Poppin Cafe
# Place Address Jaipur 302001, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Place Name: Farzi Cafe
# Place Address Radisson Jaipur City Center, Khasa Kothi Circle, Mi Road, Jaipur 302001, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Place Name: Food Junkys
# Place Address J-1, Jamna Lal Bajaj Marg, Jaipur 906202, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Place Name: Aurum
# Place Address Hilton Jaipur, 42 Geejgarh House, Hawa Sadak, Bais Godam (Hilton), Jaipur 302006, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Place Name: Nibs Cafe
# Place Address B16, Near Mgf Mall, Bhawani Singh Marg, Durga Das Colony, C Scheme, Jaipur 302001, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Place Name: Curious Life Coffee Roasters
# Place Address P 25, Yudhisthir Marg (C Scheme), Jaipur 302001, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Place Name: Chit Chat Restaurant
# Place Address D160, Kabir Marg (Bani Park,), Jaipur 302016, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Place Name: Tea Tradition
# Place Address D29-a, Chandra Niwas, Subhash Marg, C-Scheme, C Scheme, Jaipur 302001, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------

# %%
api_key = "fsq3/qWKdb9qPqlEThP0P7+f2kX52mr7qCPxMoBZAg3Ba/U="

# %%
import requests

url = "https://api.foursquare.com/v3/places/search"

params = {
    "query": "coffee",
    "ll": "26.9124,75.7873",
    "open_now": "true",
    "sort":"DISTANCE"
}

headers = {
    "Accept": "application/json",
    "Authorization": api_key
}

resp = requests.get(url, params=params, headers=headers)
resp

# %%
import requests

def get_place(query, lat, lon, sort="RELEVANCE", limit=10):
    api_key = "fsq3/qWKdb9qPqlEThP0P7+f2kX52mr7qCPxMoBZAg3Ba/U="
    url = "https://api.foursquare.com/v3/places/search"
    
    ll = f"{lat},{lon}"
    
    params = {
        "query": query,
        "ll": ll,
        "open_now": "true",
        "sort":sort,
        "limit":limit
        }

    headers = {
        "Accept": "application/json",
        "Authorization": api_key
        }
    
    resp = requests.get(url, params=params, headers=headers)
    if resp.status_code == 200:
        data = resp.json()
        for i in data['results']:
            name = i['name']
            address = i['location']['formatted_address']
            print(f"Place Name: {name}")
            print(f"Place Address {address}")
            print('-'*100)
            print('-'*100)    
            print()

# %%
get_place('pizza', 26.9124,75.7873, sort='RATING', limit=50)
# Out:
# Place Name: Tapri - The Tea House and Jizo
# Place Address B4-E, Prithviraj Road, Opposite Central Park Gate No. 4, (Prithviraj Road), Jaipur 302001, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Place Name: Moustache Hostel
# Place Address 7 Park House, M.I. Road (MI Road, Sindhi Camp), Jaipur 302001, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Place Name: Peacock Roof Top Restaurant
# Place Address Hotel Pearl Palace, 51, Hari Kishan Somani Marg, Hathroi Fort (Ajmer Rd), Jaipur 302001, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Place Name: Curious Life Coffee Roasters
# Place Address P 25, Yudhisthir Marg (C Scheme), Jaipur 302001, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Place Name: Taj Jai Mahal Palace
# Place Address Jacob Road, Jaipur 302006, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Place Name: Hotel Fairmont Jaipur Golf Course
# Place Address 2 Riico Kukas, Jaipur 303101, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Place Name: Sawai Mansingh Stadium
# Place Address Raj Path, Lalkothi, Jaipur 941735, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Place Name: Hotel Arya Niwas
# Place Address Behind Amber Tower, Sansar Chandra Road (Behind Amber Towers), Jaipur 302001, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Place Name: Jantar Mantar
# Place Address Pink City (Tulsi Marg), Jaipur 924762, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Place Name: Statue Circle
# Place Address Statue Cir, Jaipur 341023, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Place Name:
jaipur 302017, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Place Name: Aakash Institute, Vaishali Nagar
# Place Address Vaishali Nagar, Jaipur 302021, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Place Name: StudyKey
# Place Address 11/197, Bhrigu Path, Mansarovar Sector-1, Jaipur 302020, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Place Name: Ucmas
# Place Address No 186 A, Padmavati Colony (Nirman Nagar), Jaipur 302019, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Place Name: Aakash Institute Subhash Nagar
# Place Address S2/B, Arya Square Mall, Junction Of Jhotwara Road, Subhash Nagar, Shastri (Subhash Nagar), Jaipur 302016, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Place Name: Ucmas
# Place Address No 6/65 (Vidhyadhar Nagar, Sector 6), Jaipur 302023, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Place Name: Sterling Education
# Place Address 1/1227 Malviya, Jaipur 302017, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Place Name: Ucmas
# Place Address No 30, 31, Hatwara Road, Vishnu Colony (Sodala), Jaipur 302006, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Place Name: Education Overseas Consultancy Pvt. Ltd.
# Place Address 309, Okayplustower, Plot No. 5, Hatroi Gadi (Ajmer Rd,), Jaipur 302006, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# Place Name: Indo French Cultural Society
# Place Address 69 Bajaj Nagar Enclave, Bajaj (Bajaj Nagar), Jaipur 302015, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------

# %%
import requests

def get_place(query, lat, lon, sort="RELEVANCE", limit=10):
    api_key = "fsq3/qWKdb9qPqlEThP0P7+f2kX52mr7qCPxMoBZAg3Ba/U="
    url = "https://api.foursquare.com/v3/places/search"
    
    ll = f"{lat},{lon}"
    
    params = {
        "query": query,
        "ll": ll,
        "open_now": "true",
        "sort":sort,
        "limit":limit
        }

    headers = {
        "Accept": "application/json",
        "Authorization": api_key
        }
    
    resp = requests.get(url, params=params, headers=headers)
    if resp.status_code == 200:
        data = resp.json()
        for i in data['results']:
            fsq_id = i['fsq_id']
            name = i['name']
            address = i['location']['formatted_address']
            print(f"FSQ_ID: {fsq_id}")
            print(f"Place Name: {name}")
            print(f"Place Address {address}")
            print('-'*100)
            print('-'*100)    
            print()

# %%
get_place('hotels', 26.9124,75.7873, sort='RATING', limit=50)
# Out:
# FSQ_ID: 4bc7875893bdeee12e7c37ae
# Place Name: Rambagh Palace
# Place Address Bhawani Singh Road, Jaipur 302005, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# FSQ_ID: 4c4c572d712ac928bb19316e
# Place Name: The Oberoi Rajvilas
# Place Address Goner Road, Jaipur 303012, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# FSQ_ID: 4d311d2ec75a6ea8e95c01ae
# Place Name: Peacock Roof Top Restaurant
# Place Address Hotel Pearl Palace, 51, Hari Kishan Somani Marg, Hathroi Fort (Ajmer Rd), Jaipur 302001, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# FSQ_ID: 4bc7875393bdeee12a7c37ae
# Place Name: Taj Jai Mahal Palace
# Place Address Jacob Road, Jaipur 302006, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# FSQ_ID: 516c398b498ef9c062170b50
# Place Name: Hotel Fairmont Jaipur Golf Course
# Place Address 2 Riico Kukas, Jaipur 303101, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# FSQ_ID: 4bb81098314e9521fe24489d
# Place Name: Hotel Arya Niwas
# Place Address Behind Amber Tower, Sansar Chandra Road (Behind Amber Towers), Jaipur 302001, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# FSQ_ID: 4cbc54337a5d9eb0755b31e9
# Place Name: Jaipur Pavillion- ITC Rajputana
# Place Address Palace Road, Jaipur 302006, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# FSQ_ID: 4be191d48dd062b5305c3e3c
# Place Name: The Lalit
# Place Address 2B And 2C, Jagatpura Road, Jaipur 302017, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# FSQ_ID: 4bc8f091762beee173b93d38
# Place Name: Trident
# Place Address Opposite Jai Mahal, Amber Fort Road, Jaipur 302002, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# FSQ_ID: 5255020111d29a4c2a82c1e6
# Place Name: Holiday Inn Jaipur City Centre
# Place Address Commercial Plot No 1, Sardar Patel Road, Jaipur 302001, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# FSQ_ID: 537b8e8611d2cbd28ac541cf
# Place Name: Swimming Pool Crowne Plaza Jaipur Tonk Road
# Place Address Sitapura Industrial Area (Tonk Road), Jaipur 302022, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# FSQ_ID: 4bcf762d0ffdce72e281b2c0
# Place Name: Shahpura House
# Place Address D 257, Devi Marg, Banipark, Jaipur 302016, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# FSQ_ID:
Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# FSQ_ID: 522d343f11d23abbbb306720
# Place Name: Regional Science Centre and Science Park
# Place Address Behind Tb Hospital, Shastri, Jaipur 302016, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# FSQ_ID: 7a880cbf7cab4af2168a1a88
# Place Name: Club Naila
# Place Address Naila Bagh Palace, Moti Dungri Road, Jaipura, Jaipur 302004, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# FSQ_ID: 537780d1498ec49179f3de20
# Place Name: Nuyu Health Club
# Place Address Opposite Jharkhand Mahadev Temple, Queens Road, Jaipur 302021, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# FSQ_ID: 585a2fd0ea1c0d3e4d80ab7e
# Place Name: Indian Ice Cream and Kulfi Faluda
# Place Address Shop No 28, Link Road, Bapu Bazar, Jaipur 302003, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# FSQ_ID: 5ac5d7cc840fc253b7990a36
# Place Name: Chakrapani Ayurveda Clinic and Research Centre
# Place Address 8 Diamond Hill, Shanti Path, Tulsi Circle, Behind Birla Temple, Jaipur 302004, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# FSQ_ID: 5c38cbe1d0a149002c327441
# Place Name: Ki and Ka Kafe
# Place Address 274 Guru Jambeshwar Nagar, Main Gandhi Path, Jaipur 302021, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# FSQ_ID: 508e9930e4b0499bc82d04a2
# Place Name: Kababs and Curries Company
# Place Address 446 Lane Number-4, Raja Park (Raja Park), Jaipur 302004, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# FSQ_ID: 59ec9446ff0306350d59579a
# Place Name: SST Cakes and Cookies
# Place Address C 424, King Road, Nirman, Jaipur 302019, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# FSQ_ID: 56b86de6498ec22915c34eef
# Place Name: Bits and Bites
# Place Address Raja Park, Jaipur 302004, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# FSQ_ID: 502e09c3e4b0fdd3390a0778
# Place Name: Candles and Cuisines
# Place Address Ground Floor C - 18 Vaishali Marg, Jaipur 302021, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# FSQ_ID: 5be6697a112c6c003944c7cc
# Place Name: Sharma Amritsari Kulcha and Bhojnalaya
# Place Address Shop 9, Panchwati Complex, Panchwati Circle, Raja Park (Raja Park), Jaipur 302004, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# FSQ_ID: 4ed4d966722e6f1fda4704b9
# Place Name: Rajbhog Sweets and Restaurant
# Place Address Brijlalpura, Jaipur 302019, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# FSQ_ID: 4e70c91bd4c03fcb657b4bbf
# Place Name: Sahu Juice and Ice Cream Parlour
# Place Address Plot No 263, Shop No Taranagar A (Khirni Phatak Road), Jaipur 302012, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# FSQ_ID: 54b5130e498e16364a32da71
# Place Name: ZNetLive - Dedicated Servers | VPS | Web and Cloud Hosting
# Place Address D-10/52, Opposite Chitrakoot Stadium, Jaipur 302021, Rajasthan
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# FSQ_ID: 6013279974fb942944bf8083
# Place Name: Tata Motors Cars Service Centre - Kamal and Company, Tonk Road
# Place Address Ground Floor, Gopalpura Mode (Tonk Road), Jaipur 302018, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
#
# FSQ_ID: 56d70a61498e6ae9bcefb2ba
# Place Name: Hari Shankar Veg. Restro
# Place Address 104/76, Vijay Path, Mansarover (Mansarovar), Jaipur 302020, Rājasthān
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------

# %%
# %%writefile get_place_api.py

import requests

def get_place(query, lat, lon, sort="RELEVANCE", limit=10):
    api_key = "fsq3/qWKdb9qPqlEThP0P7+f2kX52mr7qCPxMoBZAg3Ba/U="
    url = "https://api.foursquare.com/v3/places/search"
    
    ll = f"{lat},{lon}"
    
    params = {
        "query": query,
        "ll": ll,
        "open_now": "true",
        "sort":sort,
        "limit":limit
        }

    headers = {
        "Accept": "application/json",
        "Authorization": api_key
        }
    
    resp = requests.get(url, params=params, headers=headers)
    if resp.status_code == 200:
        data = resp.json()
        for i in data['results']:
            fsq_id = i['fsq_id']
            name = i['name']
            address = i['location']['formatted_address']
            print(f"FSQ_ID: {fsq_id}")
            print(f"Place Name: {name}")
            print(f"Place Address {address}")
            print('-'*100)
            print('-'*100)    
            print()
# Out:
# Writing get_place_api.py
